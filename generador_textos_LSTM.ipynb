# %% [markdown]
# # Generador de municipios
# ### Erick Fernando López Fimbres.
# #### erick.lopez.fimbres@gmail.com

# %% [markdown]
# ## Definición
#
# Para la realizacion de este programa usaremos Nivel de caracter minimo y puedes consultar el archivo original [aquí](https://gist.github.com/karpathy/d4dee566867f8291f086).
# El cual nos ayudara a generar nombres de municipios caracter por caracter a partir de los ya existentes que hay en México.

# %% [markdown]
# ## Lectura del archivo

# %%
import numpy as np

municipios = open('datos/municipios.txt', 'r').read() # should be simple plain text file
caracteres = list(set(municipios))
tam_datos, tam_caracteres = len(municipios), len(caracteres)
#print ("Hay {} municipios y {} caracteres".format(municipios,caracteres))
#print(caracteres)
caracter_a_indice = { ch:i for i,ch in enumerate(caracteres) }
indice_a_caracter = { i:ch for i,ch in enumerate(caracteres) }

# %%
from __future__ import print_function

import tensorflow as tf
from tensorflow.contrib import rnn

# Import MNIST data
from tensorflow.examples.tutorials.mnist import input_data
mnist = input_data.read_data_sets("/tmp/data/", one_hot=True)

'''
To classify images using a recurrent neural network, we consider every image
row as a sequence of pixels. Because MNIST image shape is 28*28px, we will then
handle 28 sequences of 28 steps for every sample.
'''

# Training Parameters
learning_rate = 0.001
training_steps = 10000
batch_size = 128
display_step = 200

# Network Parameters
num_input = 28 # MNIST data input (img shape: 28*28)
timesteps = 28 # timesteps
num_hidden = 128 # hidden layer num of features
num_classes = 10 # MNIST total classes (0-9 digits)

# tf Graph input
X = tf.placeholder("float", [None, timesteps, num_input])
Y = tf.placeholder("float", [None, num_classes])

# Define weights
weights = {
    'out': tf.Variable(tf.random_normal([num_hidden, num_classes]))
}
biases = {
    'out': tf.Variable(tf.random_normal([num_classes]))
}


def RNN(x, weights, biases):

    # Prepare data shape to match `rnn` function requirements
    # Current data input shape: (batch_size, timesteps, n_input)
    # Required shape: 'timesteps' tensors list of shape (batch_size, n_input)

    # Unstack to get a list of 'timesteps' tensors of shape (batch_size, n_input)
    x = tf.unstack(x, timesteps, 1)

    # Define a lstm cell with tensorflow
    lstm_cell = rnn.BasicLSTMCell(num_hidden, forget_bias=1.0)

    # Get lstm cell output
    outputs, states = rnn.static_rnn(lstm_cell, x, dtype=tf.float32)

    # Linear activation, using rnn inner loop last output
    return tf.matmul(outputs[-1], weights['out']) + biases['out']

logits = RNN(X, weights, biases)
prediction = tf.nn.softmax(logits)

# Define loss and optimizer
loss_op = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits(
    logits=logits, labels=Y))
optimizer = tf.train.GradientDescentOptimizer(learning_rate=learning_rate)
train_op = optimizer.minimize(loss_op)

# Evaluate model (with test logits, for dropout to be disabled)
correct_pred = tf.equal(tf.argmax(prediction, 1), tf.argmax(Y, 1))
accuracy = tf.reduce_mean(tf.cast(correct_pred, tf.float32))

# Initialize the variables (i.e. assign their default value)
init = tf.global_variables_initializer()

# Start training
with tf.Session() as sess:

    # Run the initializer
    sess.run(init)

    for step in range(1, training_steps+1):
        batch_x, batch_y = mnist.train.next_batch(batch_size)
        # Reshape data to get 28 seq of 28 elements
        batch_x = batch_x.reshape((batch_size, timesteps, num_input))
        # Run optimization op (backprop)
        sess.run(train_op, feed_dict={X: batch_x, Y: batch_y})
        if step % display_step == 0 or step == 1:
            # Calculate batch loss and accuracy
            loss, acc = sess.run([loss_op, accuracy], feed_dict={X: batch_x,
                                                                 Y: batch_y})
            print("Step " + str(step) + ", Minibatch Loss= " + \
                  "{:.4f}".format(loss) + ", Training Accuracy= " + \
                  "{:.3f}".format(acc))

    print("Optimization Finished!")

    # Calculate accuracy for 128 mnist test images
    test_len = 128
    test_data = mnist.test.images[:test_len].reshape((-1, timesteps, num_input))
    test_label = mnist.test.labels[:test_len]
    print("Testing Accuracy:", \
        sess.run(accuracy, feed_dict={X: test_data, Y: test_label}))
# Out:
# Successfully downloaded train-images-idx3-ubyte.gz 9912422 bytes.
# Extracting /tmp/data/train-images-idx3-ubyte.gz
# Successfully downloaded train-labels-idx1-ubyte.gz 28881 bytes.
# Extracting /tmp/data/train-labels-idx1-ubyte.gz
# Successfully downloaded t10k-images-idx3-ubyte.gz 1648877 bytes.
# Extracting /tmp/data/t10k-images-idx3-ubyte.gz
# Successfully downloaded t10k-labels-idx1-ubyte.gz 4542 bytes.
# Extracting /tmp/data/t10k-labels-idx1-ubyte.gz
# Step 1, Minibatch Loss= 2.5789, Training Accuracy= 0.133
# Step 200, Minibatch Loss= 2.1629, Training Accuracy= 0.211
# Step 400, Minibatch Loss= 1.9219, Training Accuracy= 0.375
# Step 600, Minibatch Loss= 1.8484, Training Accuracy= 0.398
# Step 800, Minibatch Loss= 1.7300, Training Accuracy= 0.523
# Step 1000, Minibatch Loss= 1.6637, Training Accuracy= 0.469
# Step 1200, Minibatch Loss= 1.6977, Training Accuracy= 0.477
# Step 1400, Minibatch Loss= 1.5084, Training Accuracy= 0.539
# Step 1600, Minibatch Loss= 1.4048, Training Accuracy= 0.539
# Step 1800, Minibatch Loss= 1.3445, Training Accuracy= 0.609
# Step 2000, Minibatch Loss= 1.1725, Training Accuracy= 0.664
# Step 2200, Minibatch Loss= 1.2389, Training Accuracy= 0.586
# Step 2400, Minibatch Loss= 1.1280, Training Accuracy= 0.656
# Step 2600, Minibatch Loss= 1.0831, Training Accuracy= 0.656
# Step 2800, Minibatch Loss= 1.0547, Training Accuracy= 0.727
# Step 3000, Minibatch Loss= 1.0419, Training Accuracy= 0.648
# Step 3200, Minibatch Loss= 1.0412, Training Accuracy= 0.641
# Step 3400, Minibatch Loss= 1.0143, Training Accuracy= 0.680
# Step 3600, Minibatch Loss= 0.9860, Training Accuracy= 0.656
# Step 3800, Minibatch Loss= 0.9645, Training Accuracy= 0.711
# Step 4000, Minibatch Loss= 0.8819, Training Accuracy= 0.703
# Step 4200, Minibatch Loss= 0.8227, Training Accuracy= 0.750
# Step 4400, Minibatch Loss= 0.9051, Training Accuracy= 0.680
# Step 4600, Minibatch Loss= 0.8598, Training Accuracy= 0.734
# Step 4800, Minibatch Loss= 0.7381, Training Accuracy= 0.766
# Step 5000, Minibatch Loss= 0.8187, Training Accuracy= 0.758
# Step 5200, Minibatch Loss= 0.9621, Training Accuracy= 0.688
# Step 5400, Minibatch Loss= 0.8104, Training Accuracy= 0.766
# Step 5600, Minibatch Loss= 0.5810, Training Accuracy= 0.836
# Step 5800, Minibatch Loss= 0.7393, Training Accuracy= 0.742
# Step 6000, Minibatch Loss= 0.8133, Training Accuracy= 0.742
# Step 6200, Minibatch Loss= 0.7591, Training Accuracy= 0.758
# Step 6400, Minibatch Loss= 0.6142, Training Accuracy= 0.766
# Step 6600, Minibatch Loss= 0.7063, Training Accuracy= 0.828
# Step 6800, Minibatch Loss= 0.5474, Training Accuracy= 0.828
# Step 7000, Minibatch Loss= 0.6338, Training Accuracy= 0.805
# Step 7200, Minibatch Loss= 0.8310, Training Accuracy= 0.758
# Step 7400, Minibatch Loss= 0.7479, Training Accuracy= 0.797
# Step 7600, Minibatch Loss= 0.5952, Training Accuracy= 0.836
# Step 7800, Minibatch Loss= 0.5953, Training Accuracy= 0.805
# Step 8000, Minibatch Loss= 0.6383, Training Accuracy= 0.789
# Step 8200, Minibatch Loss= 0.5193, Training Accuracy= 0.852
# Step 8400, Minibatch Loss= 0.6220, Training Accuracy= 0.828
# Step 8600, Minibatch Loss= 0.6257, Training Accuracy= 0.812
# Step 8800, Minibatch Loss= 0.5593, Training Accuracy= 0.820
# Step 9000, Minibatch Loss= 0.5067, Training Accuracy= 0.828
# Step 9200, Minibatch Loss= 0.6114, Training Accuracy= 0.828
# Step 9400, Minibatch Loss= 0.6217, Training Accuracy= 0.789
# Step 9600, Minibatch Loss= 0.4497, Training Accuracy= 0.898
# Step 9800, Minibatch Loss= 0.6036, Training Accuracy= 0.820
# Step 10000, Minibatch Loss= 0.4711, Training Accuracy= 0.844
# Optimization Finished!
# Testing Accuracy: 0.875
