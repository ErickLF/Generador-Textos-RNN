# %% [markdown]
# # Generador de municipios
# ### Erick Fernando López Fimbres.
# #### erick.lopez.fimbres@gmail.com

# %% [markdown]
# ## Definición
#
# Para la realizacion de este programa usaremos Nivel de caracter minimo y puedes consultar el archivo original [aquí](https://gist.github.com/karpathy/d4dee566867f8291f086).
# El cual nos ayudara a generar nombres de municipios caracter por caracter a partir de los ya existentes que hay en México.

# %% [markdown]
# ## Lectura del archivo

# %%
import numpy as np

municipios = open('datos/municipios.txt', 'r').read() # should be simple plain text file
caracteres = list(set(municipios))
tam_datos, tam_caracteres = len(municipios), len(caracteres)
#print ("Hay {} municipios y {} caracteres".format(municipios,caracteres))
#print(caracteres)
caracter_a_indice = { ch:i for i,ch in enumerate(caracteres) }
indice_a_caracter = { i:ch for i,ch in enumerate(caracteres) }

# %% [markdown]
# ## Ajustes de parametros

# %%
capas_ocultas = 150 # tamaño de capas ocultas de neuronas
num_pasos = 25 # numero de pasos para el RNN
epsilon = 1e-1

# parametros del modelo
Wxh = np.random.randn(capas_ocultas, tam_caracteres)*0.01 # oculto a entrada
Whh = np.random.randn(capas_ocultas, capas_ocultas)*0.01 # oculto a oculto
Why = np.random.randn(tam_caracteres, capas_ocultas)*0.01 # oculto a la salida
bh = np.zeros((capas_ocultas, 1)) # sesgo oculto
by = np.zeros((tam_caracteres, 1)) # sesgo de salida

# %% [markdown]
# ## Funcion de perdida

# %%
def lossFun(entradas, objetivos, hprev):
    """
    entradas: una lista de enteros
    objetivos: una lista de enteros
    hprev es un arreglo de  Hx1 del estado oculto inicial
    regresa: la perdida, gradientes del modelo y el ultimo estado oculto
    """
    xs, hs, ys, ps = {}, {}, {}, {}
    hs[-1]= np.copy(hprev)
    perdida = 0
    # forward pass
    for t in range(len(entradas)):
        xs[t] = np.zeros((tam_caracteres,1)) # encode in 1-of-k representation
        xs[t][entradas[t]] = 1
        hs[t] = np.tanh(np.dot(Wxh, xs[t]) + np.dot(Whh, hs[t-1]) + bh) # hidden state
        ys[t] = np.dot(Why, hs[t]) + by # unnormalized log probabilities for next chars
        ps[t] = np.exp(ys[t]) / np.sum(np.exp(ys[t])) # probabilities for next chars
        perdida += -np.log(ps[t][objetivos[t],0]) # softmax (cross-entropy loss)
    # backward pass: compute gradients going backwards
    dWxh, dWhh, dWhy = np.zeros_like(Wxh), np.zeros_like(Whh), np.zeros_like(Why)
    dbh, dby = np.zeros_like(bh), np.zeros_like(by)
    dhnext = np.zeros_like(hs[0])
    for t in reversed(range(len(entradas))):
        dy = np.copy(ps[t])
        dy[objetivos[t]] -= 1 # backprop into y. see http://cs231n.github.io/neural-networks-case-study/#grad if confused here
        dWhy += np.dot(dy, hs[t].T)
        dby += dy
        dh = np.dot(Why.T, dy) + dhnext # backprop into h
        dhraw = (1 - hs[t] * hs[t]) * dh # backprop through tanh nonlinearity
        dbh += dhraw
        dWxh += np.dot(dhraw, xs[t].T)
        dWhh += np.dot(dhraw, hs[t-1].T)
        dhnext = np.dot(Whh.T, dhraw)
    for dparam in [dWxh, dWhh, dWhy, dbh, dby]:
        np.clip(dparam, -5, 5, out=dparam) # clip to mitigate exploding gradients
    return perdida, dWxh, dWhh, dWhy, dbh, dby, hs[len(entradas)-1]

# %%
## Muestra

# %%
def sample(h, letra_semilla, n):
    """
    muestra una secuencia de enteros del modelo
    h: estado de memoria
    letra_semilla: letra inicial para el primer caso
    """
    x = np.zeros((tam_caracteres, 1))
    x[letra_semilla] = 1
    ixes = []
    for t in range(n):
        h = np.tanh(np.dot(Wxh, x) + np.dot(Whh, h) + bh)
        y = np.dot(Why, h) + by
        p = np.exp(y) / np.sum(np.exp(y))
        ix = np.random.choice(range(tam_caracteres), p=p.ravel())
        x = np.zeros((tam_caracteres, 1))
        x[ix] = 1
        ixes.append(ix)
    return ixes

# %%
## Generando el texto

# %%
n, p = 0, 0
mWxh, mWhh, mWhy = np.zeros_like(Wxh), np.zeros_like(Whh), np.zeros_like(Why)
mbh, mby = np.zeros_like(bh), np.zeros_like(by) # memory variables for Adagrad
perdida_suave = -np.log(1.0/tam_caracteres)*num_pasos # perdida en el instante 0
while True:
    # prepare inputs (we're sweeping from left to right in steps seq_length long)
    if p+num_pasos+1 >= len(municipios) or n == 0:
        hprev = np.zeros((capas_ocultas,1)) # reset RNN memory
        p = 0 # go from start of data
    entradas = [caracter_a_indice[ch] for ch in municipios[p:p+num_pasos]]
    objetivos = [caracter_a_indice[ch] for ch in municipios[p+1:p+num_pasos+1]]
    
    # sample from the model now and then
    if n % 10000 == 0:
        sample_ix = sample(hprev, entradas[0], 200)
        txt = ''.join(indice_a_caracter[ix] for ix in sample_ix)
        print (txt,"/n")
    loss, dWxh, dWhh, dWhy, dbh, dby, hprev = lossFun(entradas, objetivos, hprev)
    perdida_suave = perdida_suave * 0.999 + loss * 0.001
    if n % 10000 == 0: print ("iteracion: {}, perdida: {} ".format(n,perdida_suave))
    
    if perdida_suave == 5: break 
    # perform parameter update with Adagrad
    for param, dparam, mem in zip([Wxh, Whh, Why, bh, by], 
                                [dWxh, dWhh, dWhy, dbh, dby], 
                                [mWxh, mWhh, mWhy, mbh, mby]):
        mem += dparam * dparam
        param += -epsilon * dparam / np.sqrt(mem + 1e-8) # adagrad updat
    
    p += num_pasos # move data pointer
    n += 1 # iteration counter
# Out:
# AdPúiNHpoAENámAFbSóÁírLrRKs
# cÑñZóNougÁjakJ
# eü.áRRi0oti6El2yFhYBmzsrsrívÑ8UNpázUtBÁd8rLb2RqgyTmzo-núEff aNioLptZúoNhxLtóAo,ORiévv-zíóXE-evKNB.hsS-
# XUURgI0
# TGPzriv0ñóLe8-.0tTyküoO6tXíEmNq
# XZ0gÑZxXSUU-Jl /n
# iteracion: 0, perdida: 105.48769291673338
# pecen
# Ahuinic
# Ana
# Num Dreres
# Ría Coolto de Ateree Axbo Yuitlán
# Acagos Aróojumocaghiab
# xganereeya Xuenas
# Andemongon Amallán
# Amateepec Yugotepec
# Acullpec
# Zuatlán
# Alóyo dec de Vcacuántos
# Anciga de Áympic /n
# iteracion: 10000, perdida: 49.04492656586881
# nana
# Apapahuatez
# Fepelo
# Son Anatzara de
# Sal Atilluc de Mayerrez
# Talzayago
# Xé Anallano
# Atondón Pidal Alulmagasiman
# Apaz
# Landane Axhuábla
# Zhiapehutlán
# Aqhitlán
# Andejo
# Bumtaricues
# Nomito
# Tlapeya
# Sanuetla /n
# iteracion: 20000, perdida: 45.22487463616341
# lol
# Charatlán
# Coepacana
# Carnorión de Cherro
# Chacío
# Ureliña
# Chuledre de Carizo
# Xoyutlán
# Canepeoguinco de lar Bexca
# Cactabito
# Tlapacahuxate
# Candame
# Copay
# Gabro
# Chiati
# Choltlal
# Zeyatlohidargo Rerero
# Huec /n
# iteracion: 30000, perdida: 43.57345566675049
# coduero
# Carido
# Cancarca
# Contico
# CuaPapanco
# Cocaltipan de Caría
# Coyatzilac
# Cuucten
# Chicanán
# Tepalta
# Comostit
# 8lapama
# Cososocil
# Chiila
# Yuzhiluac
# Agulil Huitea
# Conkolo
# Gerfiner Cucodas
# Atepa
# Zatalán
# Como /n
# iteracion: 40000, perdida: 42.239380194894714
# da Grande
# Temahuitlán
# Axtzillad
# Gzozástipuca de Atzalantelos
# Crela
# Corcos
# Chezocango
# Anuiluhua
# Cacalatlán
# Curcatlán de Hidrio Ixhuac
# Huitepelquiotlán
# Gergolo Márzotzin Ocorez de Bravo
# Chaucalocomén
# Ey /n
# iteracion: 50000, perdida: 41.465184373806885
# e
# Gantina Zánazanta
# Xoctitla
# El Sachurillán de Gorrías
# Eltoda
# Ablalla
# Ohuatepec
# Coubadeso Ziquindo
# Yontonco Día
# Aguara
# Tinillo
# Falésa detzintia de Ealtancós den I. Salvez
# Ixtepec
# Puongula
# Zeravari Mar /n
# iteracion: 60000, perdida: 40.962312765329216
#
# Huerda
# Tliat
# Hepolitlán
# Juán Dzingo Enja dre Reyos Perreror Chucuáre
# Ozhiás de San ís Lagón del Rearro
# Cualo
# Huayutza
# Huetra Suntila del Vienamas
# Cojarre
# Gumilesto Hexopa
# Capaquelpan
# gosanci
# Egus Fau /n
# iteracion: 70000, perdida: 40.28313156771117
# Senitla
# Huejicuigos
# Tlapa
# Compuacanaco
# Escihucas
# Ixacolán del More man Ipayada
# Hepea QZiatepec
# Holapa
# Ixxoyotlán
# Icarán
# Huedilgo de Jodro
# Aranas
# Guerez del seyan de Narevizo
# Royaca
# Momero
# Laliz
# Oteme
#  /n
# iteracion: 80000, perdida: 40.25892087201297
#  de Chilmriax
# Liagutill de Remó
# Singuay
# Ocamatenalcio
# Gerarez
# Nualuapa
# Nam
# Villa de Ecoimore
# Colvingos
# Lago
# Jecostepec Coatlán
# Juchutzáran
# Royón Yorringo
# Huanatla
# Pucan
# Conasa
# Jelán
# Misces
# Janquicua
# H /n
# iteracion: 90000, perdida: 39.23390560236319
# ntor Gingrengo de la Pe Doel Notatan
# Tepatlán Joséna
# El Yadrís
# Pacheo
# Cinamonas
# Marío Velave Isulápa
# Huenano el Sotínenco delorez de Ría de Ciguero
# Itustepec
# Saz
# Gerarar
# Las Mengo
# Matoco
# Mixquilla de  /n
# iteracion: 100000, perdida: 38.630437218663246
# Nagozaquititlango de lo Maro
# Huidres Talipe
# Jumonco de la Brina
# Mirdan
# Timatepec Mitaja dalco
# Blliads
# Tucámzom
# Tlaxkitla
# Orinastli de Prde G. Coreura
# Tluntiafola
# Huektlitla 2n Nuebahiamo
# Coctiencos Tl /n
# iteracion: 110000, perdida: 38.54041341735709
#
# Lochipecho
# Jollo
# Zoyoxtlán
# Villas
# Malves
# Ralío de Las Río
# Agadremón
# Rejatlán La Qreo
# Villodi
# Gres Mitzino
# Vorete
# Nen Sanade
# Cochmutlán de len
# Puen Hedaras
# San Penrenem
# La Pachutlan
# Oriz
# Nuca
# Rarinast /n
# iteracion: 120000, perdida: 38.42478655244557
# rriumo e
# Andro Nunastial Prorda
# San Nuchitlán
# Tulmo
# San del eRíní
# Pesnar
# Magosillitlán
# Nuinas
# Sanavo Pumariel Pebestlán
# Juchia
# Zahillachihuan de Gónpecres
# San Mares
# San Paltanamlo Gracualtintlán
# San M /n
# iteracion: 130000, perdida: 37.69669333764546
# n Dodamís
# Camatepec
# Puero
# San Indetoc
# Sintenco
# Fuil i den A. Puez de Nuivindio Olaccolpe
# Biden Taltzilaquitpel
# Predecas Pridor Xitlán
# Pitoncia Barjebasta
# Pagrenzo
# Sachicapa
# Peñas
# San Cioniago
# San Sel  /n
# iteracion: 140000, perdida: 36.9609661336311
# o Díayo de Jotla
# San Jeralenco del Men Lachigueracío Salala
# Santiígada
# Huicuitlán Brazotlahha
# Villa Aputzalcos
# Xantatocho
# San Jeato
# San Tezamú
# San Maguas Tuochincio Bel
# San Parrez de Ataviruí
# Palnien  /n
# iteracion: 150000, perdida: 36.2596368192387
# guratzán
# San Migrero
# San Puelos
# San Minirre de Minevo
# Prana de Riorio Zarzota
# Chincho de Mécoacas
# San Nigonaso Amblapa
# Santa Cofaliro Navostil Santiárero
# San Boliahuastlán
# San Juán Oroyo
# Tamimas
# San M /n
# iteracion: 160000, perdida: 35.46517208714214
# o Cocalucan
# San Fella
# San Mixtempoc
# Tochicuapan
# Tequixtec
# San Siné Vatepec
# La Ixhuntla
# San Juan Carhíatla
# San Itinolo
# San Miguil Yabal Botululuchepec
# San Juán Ihuepanca
# San Lor Matoalciapa
# San Mineno  /n
# iteracion: 170000, perdida: 34.65059986319476
# án
# Agdé Sandos
# San Pedro equinis Pida
# Santa Cao Jáñata
# San Pejoquestlán Cuésinal
# Santo Jiapamo
# San Pedal Villa Morínerar
# Roay
# Santicuisa
# Sanquila de Rero Mixtepec
# San Pedro Tonatz
# Santo María de de Ma /n
# iteracion: 180000, perdida: 34.19834686622145
#  Vicuas Sánrillán
# Santa María Ixtehia
# Acuitlán
# San Sefos Questanco Quinipa
# San Luerez de Tandeno Selitono Bivitarro Lo Carnanio Talatlco de Reyes de Sorejaro
# Ana Anumate
# Sana
# Huautirana La Ría Bagdalg /n
# iteracion: 190000, perdida: 33.30665166458264
#  Treraméno
# Santiago Yolia
# Vialo Tocetla
# Santa María Benava
# San Leba
# Mucta
# Santa Domes
# Santos
# Roahuata
# Saltatoya
# Santa Crigol Oro
# Papenxo
# Asotango
# Santealo Trampoc
# Sanca Amatla
# Santa Cojahuatla de Grer /n
# iteracion: 200000, perdida: 32.55670416434205
# ua Horaguillo -Méngad
# Santa María Soyal
# Santiago
# Santore de Namam Huichiletlán
# Tepa Villado
# Santa Mo. Natepimo Abranito Liteapa
# Santa Manír Gesuzápilapems
# Santa Mader Atzén
# Santia
# Nolocastépel SanRero /n
# iteracion: 210000, perdida: 31.79710553435608
#
# Villa Cragueza
# Santo Irten
# Jianutla
# Santiago Tipetla
# Salta Nucat
# Artiltitepec
# Tla
# Zamolipa
# Santo Dominfé de Corra
# Huacalpa
# Santiago y de Cartirescio
# Santa
# Malápetepec
# Santos Suchila
# Xochiñalán
# Séna M /n
# iteracion: 220000, perdida: 31.41029157794333
# cán
# Terzaa
# Santo Tolma
# Pacatió
# Mingueg
# Sota
# San Eigualín Pamolal Coza
# Yancánfilvadado
# Apamentla de Tecantla
# Tecopemenco
# Teopahuatlán
# Sos del Antoride Cialutlio
# Yamipan
# Santo Domingo deoca de Poyarí
# du /n
# iteracion: 230000, perdida: 31.604824483260956
# envel
# Cañejosco Cotzitepec
# Temaranto
# Tepacualco
# Rhilo
# Tecuylco
# Taxchico
# Tapatepec
# Tenatepec
# Ramandio
# Teojumeotian
# Tuxmeoco
# Titepeco
# Tlayoaca
# Tiotlapa
# Tajungueca
# Mín Cacincengo
# Atomaltix
# Tandala
# Santo  /n
# iteracion: 240000, perdida: 31.446937018570367
# ina
# Tematlán
# Rampos
# Gonalixtepec Siagopam
# Tenipas
# Vilpe Lerago
# Andeo
# Magusimamo
# Ajuzahicoa
# Talaquiel
# Tanatza de Vielío de Vilis Redrias de Taquinahitlóz da Carcaro
# Chiutepángo de Tlinenida Mararía
# San /n
# iteracion: 250000, perdida: 31.531270891329648
# tlango
# Temollelápa
# Santa Croztilla
# Ardinzo
# Ximumolco
# Tletepec ianago
# Zaco
# uapanipan
# Xauciaguca
# Tenen
# Tlaxcatlán
# Tuehtotepec de Bacararenca Capenec
# ViagTapaytól Tladac
# TulalcelteÁlché
# Sankuin
# Nuibas
# Xa /n
# iteracion: 260000, perdida: 31.34440067253845
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-33-ac942b78a204> in <module>()
#      16         txt = ''.join(indice_a_caracter[ix] for ix in sample_ix)
#      17         print (txt,"/n")
# ---> 18     loss, dWxh, dWhh, dWhy, dbh, dby, hprev = lossFun(entradas, objetivos, hprev)
#      19     perdida_suave = perdida_suave * 0.999 + loss * 0.001
#      20     if n % 10000 == 0: print ("iteracion: {}, perdida: {} ".format(n,perdida_suave))
#
# <ipython-input-5-6b814b8dc4d5> in lossFun(entradas, objetivos, hprev)
#      13         xs[t] = np.zeros((tam_caracteres,1)) # encode in 1-of-k representation
#      14         xs[t][entradas[t]] = 1
# ---> 15         hs[t] = np.tanh(np.dot(Wxh, xs[t]) + np.dot(Whh, hs[t-1]) + bh) # hidden state
#      16         ys[t] = np.dot(Why, hs[t]) + by # unnormalized log probabilities for next chars
#      17         ps[t] = np.exp(ys[t]) / np.sum(np.exp(ys[t])) # probabilities for next chars
#
# KeyboardInterrupt:
